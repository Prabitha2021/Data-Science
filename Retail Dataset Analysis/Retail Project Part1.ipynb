# %%
#Data Cleaning process

# %%
import pandas as pd
import numpy as np

# %%
#load dataset on python
import io
df = pd.read_csv(r'D:\Prabitha\Edubridge classes\Project\Retail data\archive\Monthly_Food_Retail_Prices.csv')

# %%
df
# Out:
#                      State          Centre Commodity     Variety Unit  \
# 0           Andhra Pradesh        Chittoor     Moong       Split  Kg.
# 1           Andhra Pradesh          Guntur     Moong       Split  Kg.
# 2           Andhra Pradesh         Kurnool     Moong       Split  Kg.
# 3           Andhra Pradesh  Vishakhapatnam     Moong       Split  Kg.
# 4        Arunachal Pradesh        Itanagar     Moong       Split  Kg.
# ...                    ...             ...       ...         ...  ...
# 1147441        West Bengal      Jalpaiguri     Wheat  Kalyan HYV  Kg.
# 1147442        West Bengal         Kolkata     Wheat        Desi  Kg.
# 1147443        West Bengal         Kolkata     Wheat  Kalyan HYV  Kg.
# 1147444        West Bengal           Malda     Wheat        Desi  Kg.
# 1147445        West Bengal           Malda     Wheat  Kalyan HYV  Kg.
#
#         Category      Date  Retail Price
# 0           Food  JAN-2001          24.0
# 1           Food  JAN-2001          26.0
# ...

# %%
#Find all the null values in the columns Comodity, Variety, Retail Price
df.isnull().sum()
# Out:
# State                0
# Centre               0
# Commodity         9720
# Variety         205578
# Unit                 0
# Category             0
# Date                 0
# Retail Price    568921
# dtype: int64

# %%
miss_commodity = df[df["Commodity"].isnull()]
miss_commodity["State"].value_counts()
#All the missing commodities are in state WB
# Out:
# West Bengal    9720
# Name: State, dtype: int64

# %%
df2 = miss_commodity[miss_commodity['Variety'].isnull() &  miss_commodity['Retail Price'].isnull()]
df2["State"].value_counts()
 #Out of 9720 missing commidities, 1367 has both Variety & Retail Price as Null
# Out:
# West Bengal    1367
# Name: State, dtype: int64

# %%
df3=miss_commodity[miss_commodity["Variety"].notnull()]
df3["Variety"].value_counts()
#the other varieties which are not null are listed here
# Out:
# FAQ                      2187
# Split                     972
# Powdered Agmark           729
# Local                     486
# Mutton                    243
# Superfine                 243
# Rohu 1Kg Size             243
# Delicious medium size     243
# Fresh                     243
# Whole                     243
# White                     243
# Amul/Any Other            243
# Common                    243
# Packet(iodized)           243
# Poultry                   243
# Desi                      243
# Name: Variety, dtype: int64

# %%
df["Commodity"].nunique()
# Out:
# 46

# %%
df["Date"].nunique()
# Out:
# 243

# %%
#this code is to update the value of missing Retail price for each commodity
product = df["Commodity"].unique()
date = df["Date"].unique()

for dt in date:
    for p in product:
        d = df[(df["Commodity"]==p) & (df["Date"]==dt) ]

        avg = d["Retail Price"].mean()
        #st = d["Retail Price"].std()
        row = d.index
        if st>10:
            df.loc[row,"Retail Price"] = d.fillna(avg)

        #print("Product Name %s || Min: %0.2f || Max: %0.2f || Avg: %0.2f || STD: %0.2f"%(p,mi,mx,avg,st))
        
        #print("Product Done: ",p)
        
    print("Finished Date: ",dt)
# Out:
# Finished Date:  JAN-2001
# Finished Date:  FEB-2001
# Finished Date:  MAR-2001
# Finished Date:  APR-2001
# Finished Date:  MAY-2001
# Finished Date:  JUN-2001
# Finished Date:  JUL-2001
# Finished Date:  AUG-2001
# Finished Date:  SEP-2001
# Finished Date:  OCT-2001
# Finished Date:  NOV-2001
# Finished Date:  DEC-2001
# Finished Date:  JAN-2002
# Finished Date:  FEB-2002
# Finished Date:  MAR-2002
# Finished Date:  APR-2002
# Finished Date:  MAY-2002
# Finished Date:  JUN-2002
# Finished Date:  JUL-2002
# Finished Date:  AUG-2002
# Finished Date:  SEP-2002
# Finished Date:  OCT-2002
# Finished Date:  NOV-2002
# Finished Date:  DEC-2002
# Finished Date:  JAN-2003
# Finished Date:  FEB-2003
# Finished Date:  MAR-2003
# Finished Date:  APR-2003
# Finished Date:  MAY-2003
# Finished Date:  JUN-2003
# Finished Date:  JUL-2003
# Finished Date:  AUG-2003
# Finished Date:  SEP-2003
# Finished Date:  OCT-2003
# Finished Date:  NOV-2003
# Finished Date:  DEC-2003
# Finished Date:  JAN-2004
# ...

# %%
df.to_csv(r"D:\Prabitha\Edubridge classes\Project\Retail data\archive\Processed_data-4-9-2021.csv")

# %%
#load dataset on python
import io
df = pd.read_csv(r'D:\Prabitha\Edubridge classes\Project\Retail data\archive\Processed_data-4-9-2021.csv')

# %%
df
# Out:
#          Unnamed: 0              State          Centre Commodity     Variety  \
# 0                 0     Andhra Pradesh        Chittoor     Moong       Split
# 1                 1     Andhra Pradesh          Guntur     Moong       Split
# 2                 2     Andhra Pradesh         Kurnool     Moong       Split
# 3                 3     Andhra Pradesh  Vishakhapatnam     Moong       Split
# 4                 4  Arunachal Pradesh        Itanagar     Moong       Split
# ...             ...                ...             ...       ...         ...
# 1147441     1147441        West Bengal      Jalpaiguri     Wheat  Kalyan HYV
# 1147442     1147442        West Bengal         Kolkata     Wheat        Desi
# 1147443     1147443        West Bengal         Kolkata     Wheat  Kalyan HYV
# 1147444     1147444        West Bengal           Malda     Wheat        Desi
# 1147445     1147445        West Bengal           Malda     Wheat  Kalyan HYV
#
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# State                0
# Centre               0
# Commodity         9720
# Variety         205578
# Unit                 0
# Category             0
# Date                 0
# Retail Price    309252
# dtype: int64
